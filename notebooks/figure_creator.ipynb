# %%
import matplotlib.pyplot as plt
import networkx as nx

from graph_models.graphs import UGRAPH

# %%
# use string node labels to match UGRAPH's type signature
mygraph = UGRAPH(edges=[("1", "2"), ("2", "3"), ("3", "1")])

# %%
G = mygraph.to_networkx()
nx.draw(G, with_labels=True)
plt.savefig("./paper/figures/mygraph.png", dpi=300, bbox_inches="tight")
plt.show()
